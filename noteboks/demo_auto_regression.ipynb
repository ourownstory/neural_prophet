# %%
import pandas as pd
from neuralprophet.neural_prophet import NeuralProphet

# %%
df = pd.read_csv('../data/example_wp_log_peyton_manning.csv')

# %% [markdown]
# # Auto-Regression

# %% [markdown]
# ## AR(1): 1 step ahead

# %%
m = NeuralProphet(
    n_forecasts=3,
    n_lags=5,
    yearly_seasonality=False,
    weekly_seasonality=False,
    daily_seasonality=False,
)
metrics = m.fit(df)
metrics
# Out:
#     SmoothL1Loss       MAE  RegLoss
# 0       0.448603  0.680471      0.0
# 1       0.252782  0.467241      0.0
# 2       0.193331  0.392781      0.0
# 3       0.169173  0.360772      0.0
# 4       0.158190  0.348200      0.0
# 5       0.151652  0.337694      0.0
# 6       0.147324  0.331516      0.0
# 7       0.146089  0.329809      0.0
# 8       0.145816  0.328894      0.0
# 9       0.144726  0.327346      0.0
# 10      0.144842  0.327668      0.0
# 11      0.144839  0.327502      0.0
# 12      0.145035  0.327387      0.0
# 13      0.144864  0.327546      0.0
# 14      0.144877  0.327376      0.0
# 15      0.145539  0.329479      0.0
# 16      0.144601  0.327364      0.0
# 17      0.144286  0.326270      0.0
# 18      0.144690  0.327622      0.0
# 19      0.145595  0.328881      0.0
# 20      0.146622  0.330028      0.0
# 21      0.144442  0.326692      0.0
# 22      0.145486  0.329722      0.0
# 23      0.145082  0.325872      0.0
# 24      0.144699  0.328415      0.0
# ...

# %%
future = m.compose_prediction_df(df, n_history=len(df))
forecast = m.predict(future)
fig_fit = m.plot(forecast)

# %%
fig_comp = m.plot_components(forecast)

# %%
fig_param = m.plot_parameters()

# %% [markdown]
# ### AR(60): 1 step ahead

# %%
m = NeuralProphet(
    n_forecasts=1,
    n_lags=60,
    yearly_seasonality=False,
    weekly_seasonality=False,
    daily_seasonality=False,
)
metrics = m.fit(df)

# %%
future = m.compose_prediction_df(df, n_history=len(df))
forecast = m.predict(future)
fig_fit = m.plot(forecast)

# %%
fig_param = m.plot_parameters()

# %% [markdown]
# ### AR(60): 1-30 step ahead

# %%
m = NeuralProphet(
    n_forecasts=30,
    n_lags=60,
    yearly_seasonality=False,
    weekly_seasonality=False,
    daily_seasonality=False,
)
metrics = m.fit(df)

# %%
future = m.compose_prediction_df(df, n_history=len(df))
forecast = m.predict(future)
fig_fit = m.plot(forecast)

# %%
fig_param = m.plot_parameters()

# %%
future = m.compose_prediction_df(df, n_history=60)
forecast = m.predict(future)
fig_fit = m.set_forecast_in_focus(30).plot(forecast)

# %%
fig_fit = m.set_forecast_in_focus(1).plot(forecast)

# %%
fig_prediction = m.plot_last_forecast(forecast, include_previous_n=2)

# %% [markdown]
# ### AR(60): 1-30 step ahead, Sparse weights

# %%
m = NeuralProphet(
    n_forecasts=30,
    n_lags=60,
    ar_sparsity=0.01,
    yearly_seasonality=False,
    weekly_seasonality=False,
    daily_seasonality=False,
)
metrics = m.fit(df)

# %%
future = m.compose_prediction_df(df, n_history=len(df))
forecast = m.predict(future)
fig_fit = m.plot(forecast)

# %%
fig_param = m.plot_parameters()

# %%
fig_param = m.set_forecast_in_focus(30).plot_parameters()

# %%
# fig_prediction = m.plot_last_forecast(forecast, include_previous_n=2)
