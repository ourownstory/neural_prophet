# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ourownstory/neural_prophet/blob/main/tutorials/feature-use/trend_peyton_manning.ipynb)

# %% [markdown]
# # Fitting a changing trend
#
# We will use the time series of the log daily page views for the Wikipedia page for Peyton Manning as an example to illustrate how to fit a changing trend.
#
# First, we load the data:

# %%
if "google.colab" in str(get_ipython()):
    # !pip install git+https://github.com/ourownstory/neural_prophet.git # may take a while
    #!pip install neuralprophet # much faster, but may not have the latest upgrades/bugfixes

import pandas as pd
from neuralprophet import NeuralProphet, set_log_level

set_log_level("ERROR")

# %%
data_location = "https://raw.githubusercontent.com/ourownstory/neuralprophet-data/main/datasets/"
df = pd.read_csv(data_location + "wp_log_peyton_manning.csv")
df.head(3)
# Out:
#            ds       y
# 0  2007-12-10  9.5908
# 1  2007-12-11  8.5196
# 2  2007-12-12  8.1837

# %% [markdown]
# Now we can fit an initial model without any customizations.
#
# We specify the data frequency to be daily. The model will remember this later when we predict into the future.

# %%
m = NeuralProphet(epochs=2, n_forecasts=300, n_lags=100, trend_reg=0)

metrics = m.fit(df, freq="D" )
metrics.head(3)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/env/lib/python3.8/site-packages/pytorch_lightning/trainer/configuration_validator.py:117: PossibleUserWarning: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
#   rank_zero_warn(
#
# Loading `train_dataloader` to estimate number of stepping batches.
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/env/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:225: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Finding best initial lr:   0%|          | 0/235 [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=2` reached.
# LR finder stopped early after 162 steps due to diverging loss.
# Restoring states from the checkpoint path at /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/tutorials/feature-use/.lr_find_285c0828-2996-4526-bee6-6cedacbcdcb4.ckpt
# Loading `train_dataloader` to estimate number of stepping batches.
# ┏━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓
# ┃   ┃ Name          ┃ Type             ┃ Params ┃
# ┡━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩
# │ 0 │ metrics_train │ MetricCollection │      0 │
# │ 1 │ metrics_val   │ MetricCollection │      0 │
# │ 2 │ season_params │ ParameterDict    │     18 │
# │ 3 │ ar_net        │ ModuleList       │ 30.0 K │
# └───┴───────────────┴──────────────────┴────────┘
# Trainable params: 30.0 K
# Non-trainable params: 0
# Total params: 30.0 K
# Total estimated model params size (MB): 0
# Output()
# `Trainer.fit` stopped: `max_epochs=2` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#         MAE      RMSE      Loss  RegLoss  epoch
# 0  2.446026  3.153169  0.213038      0.0      0
# 1  0.648862  0.843548  0.013647      0.0      1

# %% [markdown]
# The returned metrics dataframe contains recoded metrics for each training epoch.
#
# Next, we create a dataframe to predict on.
# Here, we specify that we want to predict one year into the future and that we want to include the entire history.

# %%
future = m.make_future_dataframe(df, periods=365, n_historic_predictions=True)
future.tail(3)
# Out:
#              ds     y
# 3261 2016-11-13  None
# 3262 2016-11-14  None
# 3263 2016-11-15  None

# %% [markdown]
# Note: 'y' and 'y_scaled' are not given for the period extending into the future, as we do not know their true values.

# %%
forecast = m.predict(future)
print(list(forecast.columns))
# Out:
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/env/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:225: PossibleUserWarning: The dataloader, predict_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2822: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[f"residual{forecast_lag}"] = yhat - df_forecast["y"]
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2825: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# ...
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
#
# WARNING - (py.warnings._showwarnmsg) - /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2847: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_forecast[name] = yhat
# ['ds', 'y', 'residual1', 'yhat1', 'residual2', 'yhat2', 'residual3', 'yhat3', 'residual4', 'yhat4', 'residual5', 'yhat5', 'residual6', 'yhat6', 'residual7', 'yhat7', 'residual8', 'yhat8', 'residual9', 'yhat9', 'residual10', 'yhat10', 'residual11', 'yhat11', 'residual12', 'yhat12', 'residual13', 'yhat13', 'residual14', 'yhat14', 'residual15', 'yhat15', 'residual16', 'yhat16', 'residual17', 'yhat17', 'residual18', 'yhat18', 'residual19', 'yhat19', 'residual20', 'yhat20', 'residual21', 'yhat21', 'residual22', 'yhat22', 'residual23', 'yhat23', 'residual24', 'yhat24', 'residual25', 'yhat25', 'residual26', 'yhat26', 'residual27', 'yhat27', 'residual28', 'yhat28', 'residual29', 'yhat29', 'residual30', 'yhat30', 'residual31', 'yhat31', 'residual32', 'yhat32', 'residual33', 'yhat33', 'residual34', 'yhat34', 'residual35', 'yhat35', 'residual36', 'yhat36', 'residual37', 'yhat37', 'residual38', 'yhat38', 'residual39', 'yhat39', 'residual40', 'yhat40', 'residual41', 'yhat41', 'residual42', 'yhat42', 'residual43', 'yhat43', 'residual44', 'yhat44', 'residual45', 'yhat45', 'residual46', 'yhat46', 'residual47', 'yhat47', 'residual48', 'yhat48', 'residual49', 'yhat49', 'residual50', 'yhat50', 'residual51', 'yhat51', 'residual52', 'yhat52', 'residual53', 'yhat53', 'residual54', 'yhat54', 'residual55', 'yhat55', 'residual56', 'yhat56', 'residual57', 'yhat57', 'residual58', 'yhat58', 'residual59', 'yhat59', 'residual60', 'yhat60', 'residual61', 'yhat61', 'residual62', 'yhat62', 'residual63', 'yhat63', 'residual64', 'yhat64', 'residual65', 'yhat65', 'residual66', 'yhat66', 'residual67', 'yhat67', 'residual68', 'yhat68', 'residual69', 'yhat69', 'residual70', 'yhat70', 'residual71', 'yhat71', 'residual72', 'yhat72', 'residual73', 'yhat73', 'residual74', 'yhat74', 'residual75', 'yhat75', 'residual76', 'yhat76', 'residual77', 'yhat77', 'residual78', 'yhat78', 'residual79', 'yhat79', 'residual80', 'yhat80', 'residual81', 'yhat81', 'residual82', 'yhat82', 'residual83', 'yhat83', 'residual84', 'yhat84', 'residual85', 'yhat85', 'residual86', 'yhat86', 'residual87', 'yhat87', 'residual88', 'yhat88', 'residual89', 'yhat89', 'residual90', 'yhat90', 'residual91', 'yhat91', 'residual92', 'yhat92', 'residual93', 'yhat93', 'residual94', 'yhat94', 'residual95', 'yhat95', 'residual96', 'yhat96', 'residual97', 'yhat97', 'residual98', 'yhat98', 'residual99', 'yhat99', 'residual100', 'yhat100', 'residual101', 'yhat101', 'residual102', 'yhat102', 'residual103', 'yhat103', 'residual104', 'yhat104', 'residual105', 'yhat105', 'residual106', 'yhat106', 'residual107', 'yhat107', 'residual108', 'yhat108', 'residual109', 'yhat109', 'residual110', 'yhat110', 'residual111', 'yhat111', 'residual112', 'yhat112', 'residual113', 'yhat113', 'residual114', 'yhat114', 'residual115', 'yhat115', 'residual116', 'yhat116', 'residual117', 'yhat117', 'residual118', 'yhat118', 'residual119', 'yhat119', 'residual120', 'yhat120', 'residual121', 'yhat121', 'residual122', 'yhat122', 'residual123', 'yhat123', 'residual124', 'yhat124', 'residual125', 'yhat125', 'residual126', 'yhat126', 'residual127', 'yhat127', 'residual128', 'yhat128', 'residual129', 'yhat129', 'residual130', 'yhat130', 'residual131', 'yhat131', 'residual132', 'yhat132', 'residual133', 'yhat133', 'residual134', 'yhat134', 'residual135', 'yhat135', 'residual136', 'yhat136', 'residual137', 'yhat137', 'residual138', 'yhat138', 'residual139', 'yhat139', 'residual140', 'yhat140', 'residual141', 'yhat141', 'residual142', 'yhat142', 'residual143', 'yhat143', 'residual144', 'yhat144', 'residual145', 'yhat145', 'residual146', 'yhat146', 'residual147', 'yhat147', 'residual148', 'yhat148', 'residual149', 'yhat149', 'residual150', 'yhat150', 'residual151', 'yhat151', 'residual152', 'yhat152', 'residual153', 'yhat153', 'residual154', 'yhat154', 'residual155', 'yhat155', 'residual156', 'yhat156', 'residual157', 'yhat157', 'residual158', 'yhat158', 'residual159', 'yhat159', 'residual160', 'yhat160', 'residual161', 'yhat161', 'residual162', 'yh ...

# %%
from copy import copy 
k_t = copy(m.model.locals_vis['k_t'])
m_t = copy(m.model.locals_vis['m_t'])
t = copy(m.model.locals_vis['t'])
trend_k0 = copy(m.model.trend_k0)

# %%
import torch
result = ((trend_k0.permute(1, 2, 0) + k_t) * torch.unsqueeze(t, dim=2) + m_t)
result.shape
# Out:
# torch.Size([817, 300, 1])

# %%
k_t.shape
# Out:
# torch.Size([817, 300, 1])

# %%
m = m.highlight_nth_step_ahead_of_each_forecast(1)
m.plot_parameters()

# %% [markdown]
# The returned forecast dataframe contains the original datestamps, 'y' values, the predicted 'yhat' values, residuals and all the individual model components.

# %%
m = m.highlight_nth_step_ahead_of_each_forecast(1)
metrics
# Out:
#          MAE      RMSE      Loss  RegLoss  epoch
# 0   4.309664  5.491347  0.433416      0.0      0
# 1   2.453752  3.078514  0.173630      0.0      1
# 2   0.915734  1.163896  0.026620      0.0      2
# 3   0.654689  0.848194  0.013731      0.0      3
# 4   0.573723  0.753664  0.010865      0.0      4
# 5   0.559336  0.735358  0.010367      0.0      5
# 6   0.528441  0.699828  0.009364      0.0      6
# 7   0.509162  0.675563  0.008734      0.0      7
# 8   0.491079  0.652871  0.008159      0.0      8
# 9   0.468678  0.627957  0.007535      0.0      9
# 10  0.445640  0.600485  0.006869      0.0     10
# 11  0.429296  0.582557  0.006467      0.0     11
# 12  0.410463  0.561951  0.006007      0.0     12
# 13  0.401449  0.551928  0.005780      0.0     13
# 14  0.387537  0.536669  0.005464      0.0     14
# 15  0.376746  0.525734  0.005234      0.0     15
# 16  0.370247  0.518933  0.005100      0.0     16
# 17  0.363164  0.511795  0.004967      0.0     17
# 18  0.359042  0.507972  0.004884      0.0     18
# 19  0.355943  0.504811  0.004816      0.0     19

# %%
forecast[200:][['ds','y', 'residual1','yhat1', 'residual100','yhat100']]
# Out:
#              ds       y residual1     yhat1 residual100   yhat100
# 200  2008-06-27  7.0917 -0.685584  6.406116   -0.313911  6.777789
# 201  2008-06-28  7.0121 -0.741491  6.270609   -0.928028  6.084072
# 202  2008-06-29  6.8575 -0.262466  6.595034   -0.724977  6.132523
# 203  2008-06-30  6.8276  0.061217  6.888817   -0.114208  6.713392
# 204  2008-07-01  6.9789 -0.475691  6.503209   -0.536358  6.442542
# ...         ...     ...       ...       ...         ...       ...
# 3259 2016-11-11     NaN       NaN      None         NaN      None
# 3260 2016-11-12     NaN       NaN      None         NaN      None
# 3261 2016-11-13     NaN       NaN      None         NaN      None
# 3262 2016-11-14     NaN       NaN      None         NaN      None
# 3263 2016-11-15     NaN       NaN      None         NaN      None
#
# [3064 rows x 6 columns]

# %%
# plots the model predictions
m = m.highlight_nth_step_ahead_of_each_forecast(1)
fig1 = m.plot(forecast)

# %%
# plots the model predictions
m = m.highlight_nth_step_ahead_of_each_forecast(100)
fig1 = m.plot(forecast)

# %%
np.random.rand(9) - 0.5
# Out:
# array([ 0.06763119, -0.31147962, -0.05508632,  0.38975901, -0.17553969,
#         0.24526914, -0.45234013,  0.24312404,  0.0337211 ])

# %%
import numpy as np
import matplotlib.pyplot as plt
slope_deltas = np.array([2,2,3,5,6,3,2,1,-1])
# slope_deltas = -0.5+np.random.rand(9)
    
slope = np.trapz(slope_deltas)
distance_all = 10
distance_last = 20
time_series_slopes_history = np.concatenate([np.repeat(slope_deltas, distance_all) , np.repeat(slope_deltas[-1], distance_last - distance_all)], axis=0)

time_series_history = []
for i, sl_d in enumerate(time_series_slopes_history):
    if i == 0:
        time_series_history.append(0)
    else:
        time_series_history.append(sl_d + time_series_history[i-1])
time_series_history = np.array(time_series_history)

# %%
from time import time

# %%
n_forecasts = 100
stabilising_ratio = 1 # [0,1]
fading_factor = 0.4 # [0,1]
k_d = 1
k_p = 1

def slope_finder(stabilising_ratio, time_series_history, fading_factor, n_forecast):
    hist_size = len(time_series_history)
    time_frame_covered = (min(1, n_forecast / hist_size) ** fading_factor) * (1 / stabilising_ratio)
    print(time_frame_covered)
    return np.mean(time_series_slopes_history[-int(len(time_series_slopes_history) * time_frame_covered + 1) -1 :-1])

time_series_forecast = []
time_series_forecast_2 = []
time_series_forecast_3 = []
decay = 0.001

slope_array = []
for i in range(n_forecasts):
    time_series_forecast_i = time_series_history[-1] + (i+1) * slope_finder(stabilising_ratio, time_series_history,fading_factor, i+1)
    time_series_forecast.append(time_series_forecast_i)
    if i == 0:
        time_series_forecast_2_i = (time_series_history[-1] + slope_finder(stabilising_ratio, time_series_history,fading_factor, i+1))
    else:
        time_series_forecast_2_i = (time_series_forecast_2[i-1] + slope_finder(stabilising_ratio, time_series_history,fading_factor, i+1))
    time_series_forecast_2.append(time_series_forecast_2_i)
    
    
    time_series_forecast_3.append(time_series_forecast_i + (2.71**(-decay*i))*((time_series_forecast_2_i - time_series_forecast_i))  )

    slope_array.append(slope_finder(stabilising_ratio, time_series_history,fading_factor, i+1))
time_series_forecast = np.array(time_series_forecast)
time_series_forecast_2 = np.array(time_series_forecast_2)
time_series_forecast_3 = np.array(time_series_forecast_3)

slope_array = np.array(slope_array)
# Out:
# 0.15848931924611134
# 0.15848931924611134
# 0.15848931924611134
# 0.20912791051825463
# 0.20912791051825463
# 0.20912791051825463
# 0.2459509485849363
# 0.2459509485849363
# 0.2459509485849363
# 0.27594593229224296
# 0.27594593229224296
# 0.27594593229224296
# 0.30170881682725814
# 0.30170881682725814
# 0.30170881682725814
# 0.32453422231992085
# 0.32453422231992085
# 0.32453422231992085
# 0.3451749065980082
# 0.3451749065980082
# 0.3451749065980082
# 0.36411284060521604
# 0.36411284060521604
# 0.36411284060521604
# 0.3816778909618176
# 0.3816778909618176
# 0.3816778909618176
# 0.39810717055349726
# 0.39810717055349726
# 0.39810717055349726
# 0.41357766227900516
# 0.41357766227900516
# 0.41357766227900516
# 0.4282254736676647
# 0.4282254736676647
# 0.4282254736676647
# 0.44215785112818556
# 0.44215785112818556
# 0.44215785112818556
# 0.4554610198563667
# 0.4554610198563667
# 0.4554610198563667
# 0.4682054920046205
# 0.4682054920046205
# 0.4682054920046205
# 0.48044977359257246
# 0.48044977359257246
# 0.48044977359257246
# 0.4922430222531833
# 0.4922430222531833
# 0.4922430222531833
# 0.5036269964912325
# 0.5036269964912325
# 0.5036269964912325
# 0.5146375138577377
# 0.5146375138577377
# 0.5146375138577377
# 0.5253055608807534
# 0.5253055608807534
# 0.5253055608807534
# 0.5356581510307666
# 0.5356581510307666
# 0.5356581510307666
# 0.5457189970961078
# 0.5457189970961078
# 0.5457189970961078
# 0.5555090446573473
# 0.5555090446573473
# 0.5555090446573473
# 0.5650469000989533
# 0.5650469000989533
# 0.5650469000989533
# 0.5743491774985174
# 0.5743491774985174
# 0.5743491774985174
# 0.5834307823739845
# 0.5834307823739845
# 0.5834307823739845
# 0.5923051457504459
# 0.5923051457504459
# 0.5923051457504459
# 0.6009844187491662
# 0.6009844187491662
# 0.6009844187491662
# 0.6094796355190842
# 0.6094796355190842
# 0.6094796355190842
# 0.6178008505674119
# 0.6178008505674119
# 0.6178008505674119
# 0.6259572552252427
# 0.6259572552252427
# 0.6259572552252427
# 0.6339572769844454
# 0.6339572769844454
# 0.6339572769844454
# 0.6418086646779356
# 0.6418086646779356
# 0.6418086646779356
# 0.6495185618858332
# 0.6495185618858332
# 0.6495185618858332
# 0.6570935704911838
# 0.6570935704911838
# 0.6570935704911838
# 0.664539805948974
# 0.664539805948974
# 0.664539805948974
# 0.6718629455476418
# 0.6718629455476418
# 0.6718629455476418
# 0.6790682707157799
# 0.6790682707157799
# 0.6790682707157799
# 0.6861607042452013
# 0.6861607042452013
# 0.6861607042452013
# 0.6931448431551464
# 0.6931448431551464
# 0.6931448431551464
# 0.7000249878036358
# 0.7000249878036358
# 0.7000249878036358
# 0.7068051677550784
# 0.7068051677550784
# 0.7068051677550784
# 0.7134891648337663
# 0.7134891648337663
# 0.7134891648337663
# 0.7200805337273644
# 0.7200805337273644
# 0.7200805337273644
# 0.7265826204502337
# 0.7265826204502337
# 0.7265826204502337
# 0.7329985789312627
# 0.7329985789312627
# 0.7329985789312627
# 0.7393313859531326
# 0.7393313859531326
# 0.7393313859531326
# 0.7455838546382703
# 0.7455838546382703
# 0.7455838546382703
# 0.7517586466500455
# 0.7517586466500455
# 0.7517586466500455
# 0.757858283255199
# 0.757858283255199
# 0.757858283255199
# 0.7638851553743224
# 0.7638851553743224
# 0.7638851553743224
# 0.7698415327308915
# 0.7698415327308915
# 0.7698415327308915
# 0.7757295721954028
# 0.7757295721954028
# 0.7757295721954028
# 0.7815513254092056
# 0.7815513254092056
# 0.7815513254092056
# 0.7873087457623337
# 0.7873087457623337
# 0.7873087457623337
# 0.7930036947907745
# 0.7930036947907745
# 0.7930036947907745
# 0.7986379480509348
# 0.7986379480509348
# 0.7986379480509348
# 0.804213200522412
# 0.804213200522412
# 0.804213200522412
# 0.809731071584388
# 0.809731071584388
# 0.809731071584388
# 0.8151931096059227
# 0.8151931096059227
# 0.8151931096059227
# 0.8206007961860093
# 0.8206007961860093
# 0.8206007961860093
# 0.8259555500753953
# 0.8259555500753953
# 0.8259555500753953
# 0.8312587308087805
# 0.8312587308087805
# 0.8312587308087805
# 0.8365116420730185
# 0.8365116420730185
# 0.8365116420730185
# 0.8417155348343195
# 0.8417155348343195
# 0.8417155348343195
# 0.8468716102451239
# 0.8468716102451239
# 0.8468716102451239
# 0.851981022349263
# 0.851981022349263
# 0.851981022349263
# 0.8570448806021906
# 0.8570448806021906
# 0.8570448806021906
# 0.8620642522214542
# 0.8620642522214542
# 0.8620642522214542
# 0.8670401643811234
# 0.8670401643811234
# 0.8670401643811234
# 0.8719736062626093
# 0.8719736062626093
# 0.8719736062626093
# 0.8768655309731552
# 0.8768655309731552
# 0.8768655309731552
# 0.8817168573422499
# 0.8817168573422499
# 0.8817168573422499
# 0.8865284716052917
# 0.8865284716052917
# 0.8865284716052917
# 0.8913012289830017
# 0.8913012289830017
# 0.8913012289830017
# 0.8960359551643409
# 0.8960359551643409
# 0.8960359551643409
# 0.9007334477000148
# 0.9007334477000148
# 0.9007334477000148
# 0.9053944773130433
# 0.9053944773130433
# 0.9053944773130433
# 0.9100197891323273
# 0.9100197891323273
# 0.9100197891323273
# 0.9146101038546527
# 0.9146101038546527
# 0.9146101038546527
# 0.9191661188401216
# 0.9191661188401216
# 0.9191661188401216
# 0.9236885091455962
# 0.9236885091455962
# 0.9236885091455962
# 0.9281779285003757
# 0.9281779285003757
# 0.9281779285003757
# 0.9326350102279886
# 0.9326350102279886
# 0.9326350102279886
# 0.9370603681176802
# 0.9370603681176802
# 0.9370603681176802
# 0.9414545972489001
# 0.9414545972489001
# 0.9414545972489001
# 0.9458182747718376
# 0.9458182747718376
# 0.9458182747718376
# 0.9501519606468252
# 0.9501519606468252
# 0.9501519606468252
# 0.9544561983452209
# 0.9544561983452209
# 0.9544561983452209
# 0.9587315155141827
# 0.9587315155141827
# 0.9587315155141827
# 0.9629784246075759
# 0.9629784246075759
# 0.9629784246075759
# 0.9671974234850909
# 0.9671974234850909
# 0.9671974234850909
# 0.9713889959815001
# 0.9713889959815001
# 0.9713889959815001
# 0.9755536124478463
# 0.9755536124478463
# 0.9755536124478463
# 0.9796917302662298
# 0.9796917302662298
# 0.9796917302662298
# 0.9838037943397453
# 0.9838037943397453
# 0.9838037943397453
# 0.9878902375590143
# 0.9878902375590143
# 0.9878902375590143
# 0.99195148124666
# 0.99195148124666
# 0.99195148124666
# 0.9959879355809816
# 0.9959879355809816
# 0.9959879355809816
# 1.0
# 1.0
# 1.0

# %%
slope_finder(stabilising_ratio, time_series_history, fading_factor, 10)
# Out:
# 0.39810717055349726
# 0.35

# %%
plt.plot( np.concatenate([time_series_history, time_series_forecast], axis=0))

plt.plot( np.concatenate([time_series_history, time_series_forecast_2], axis=0))
plt.plot( np.concatenate([time_series_history, time_series_forecast_3], axis=0))

# %%
slope_finder(stabilising_ratio, time_series_history, 9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 slope_finder(stabilising_ratio, time_series_history, 9)
#
# TypeError: slope_finder() missing 1 required positional argument: 'n_forecast'

# %%
int(n_forecast *stabilising_ratio) + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 int(n_forecast *stabilising_ratio) + 1
#
# NameError: name 'n_forecast' is not defined

# %%
# plots the individual forecast components for the given time period.
# fig = m.plot_components(forecast, residuals=True)

# %%
# visualizes the model parameters.
fig2 = m.plot_parameters()

# %% [markdown]
# ## Adjusting Trend
#
# The default values work fairly well in this example. However, the default of 5 changepoints may not be adequate if the actual change in trend happens to fall in a region between the points.
#
# ### Increasing Trend Flexibility
# We can address this by increasing the number of changepoints, giving the trend more flexibility, at the danger of overfitting.
#
# Let's try what happens if we increase the number of changepoints to 30.
# Additionally, we can increase the range of data on which we fit trend changepoints to only exlude the last 10 percent (default is 20 percent).
#
# Further, we can limit the trend flexibility by regularizing it.

# %%
m = NeuralProphet(
    n_changepoints=30,
    changepoints_range=0.90,
    trend_reg=1,
)
metrics = m.fit(df, freq="D")
forecast = m.predict(df)

# %%
fig1 = m.plot(forecast)
fig2 = m.plot_parameters()

# %% [markdown]
# Looking at the trend rate changes it becomes evident that the trend is overfitting to short-term fluctuations.

# %% [markdown]
# ## Manual Trend Changepoints
# You can also manually specify the trend changepoints.
#
# Note: A changepoint will always be added at the beginning. You can ignore it.

# %%
m = NeuralProphet(
    changepoints=["2012-01-01", "2014-01-01"],
)
metrics = m.fit(df, freq="D")
forecast = m.predict(df)
# Out:
#   0%|          | 0/137 [00:00<?, ?it/s]
#   0%|          | 0/137 [00:00<?, ?it/s]

# %%
fig1 = m.plot(forecast)
fig2 = m.plot_parameters()
