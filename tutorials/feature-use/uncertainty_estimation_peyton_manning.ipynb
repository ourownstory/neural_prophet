# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ourownstory/neural_prophet/blob/master/example_notebooks/uncertainty_estimation.ipynb)

# %% [markdown]
# # Overall Uncertainty Estimation
# NeuralProphet allows the modelling of overall prediction intervals. We use the standard pinball loss function in the model to estimate different quantiles specified by the user, without any other distributional assumptions. Here, we demonstrate this feature using the peyton manning dataset.

# %%
if 'google.colab' in str(get_ipython()):
    # !pip install git+https://github.com/ourownstory/neural_prophet.git # may take a while
    #!pip install neuralprophet # much faster, but may not have the latest upgrades/bugfixes

import pandas as pd
from neuralprophet import NeuralProphet, set_log_level
set_log_level("ERROR")

# %%
data_location = "https://raw.githubusercontent.com/ourownstory/neuralprophet-data/main/datasets/"
df = pd.read_csv(data_location + "wp_log_peyton_manning.csv")
df.head(3)
# Out:
#            ds       y
# 0  2007-12-10  9.5908
# 1  2007-12-11  8.5196
# 2  2007-12-12  8.1837

# %% [markdown]
# # Basic Functionality
# For estimating the 0.1 and 0.9 quantiles, or a prediction/confidence interval (PI) of 0.8, the NeuralProphet object can be created as follows by
# specifying the required quantiles (in between (0,1)) in a list. The 0.5 quantile is always modelled by default.
# The progression of the PinballLoss values through the training epochs can be seen.

# %%
pi = 0.8                         # prediction interval
qts = [(1-pi)/2, pi + (1-pi)/2]  # quantiles based on the prediction interval
qts
# Out:
# [0.09999999999999998, 0.9]

# %%
m = NeuralProphet(quantiles=qts)
metrics = m.fit(df, freq="D")
# Out:
#   0%|          | 0/137 [00:00<?, ?it/s]
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([32, 1, 1])) that is different to the input size (torch.Size([32, 1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([274, 1, 1])) that is different to the input size (torch.Size([274, 1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([20, 1, 1])) that is different to the input size (torch.Size([20, 1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#   0%|          | 0/137 [00:00<?, ?it/s]
#   0%|          | 0/141 [00:00<?, ?it/s]WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([32, 1, 3])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([20, 1, 3])) that is different to the input size (torch.Size([20, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)

# %%
future = m.make_future_dataframe(df, periods=30, n_historic_predictions=100)
forecast = m.predict(df=future)

# %% [markdown]
# The forecasts df now has columns designated for the different quantiles of the output yhat1. For the
# components, only the 50% quantile is shown in the current state of this feature. The uncertainty bands can
# be plotted as below.

# %%
fig_forec = m.plot(forecast)

# %% [markdown]
# Similarly the components and parameters can be plotted for the 0.5th quantile.

# %%
fig_comp = m.plot_components(forecast)
fig_param = m.plot_parameters()

# %% [markdown]
# All the other features of the model, such as events, regressors, regularization etc. can be used along with
# the quantiles.

# %%
playoffs = pd.DataFrame({
    'event': 'playoff',
    'ds': pd.to_datetime([
        '2008-01-13', '2009-01-03', '2010-01-16',
        '2010-01-24', '2010-02-07', '2011-01-08',
        '2013-01-12', '2014-01-12', '2014-01-19',
        '2014-02-02', '2015-01-11', '2016-01-17',
        '2016-01-24', '2016-02-07',
    ]),
})

superbowls = pd.DataFrame({
    'event': 'superbowl',
    'ds': pd.to_datetime([
        '2010-02-07', '2012-02-05', '2014-02-02',
        '2016-02-07',
    ]),
})

events_df = pd.concat((playoffs, superbowls))

# NeuralProphet Object
m = NeuralProphet(
    quantiles=qts,
    seasonality_reg=1.5,
)

# set the model to expect these events
m = m.add_events(["playoff", "superbowl"], regularization=0.1)

# create the data df with events
history_df = m.create_df_with_events(df, events_df)
metrics = m.fit(history_df, freq="D")
# Out:
#   0%|          | 0/137 [00:00<?, ?it/s]
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([32, 1, 1])) that is different to the input size (torch.Size([32, 1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([274, 1, 1])) that is different to the input size (torch.Size([274, 1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([20, 1, 1])) that is different to the input size (torch.Size([20, 1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#   0%|          | 0/137 [00:00<?, ?it/s]
#   0%|          | 0/141 [00:00<?, ?it/s]WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([32, 1, 3])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([20, 1, 3])) that is different to the input size (torch.Size([20, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)

# %%
future = m.make_future_dataframe(history_df, events_df, periods=30, n_historic_predictions=100)
forecast = m.predict(df=future)
fig_forec = m.plot(forecast)

# %% [markdown]
# ## Different Base Loss Functions
# In the standard pinball loss, the base error is just the difference between the actuals and the
# predicted. However, in NeuralProphet we provide the user, the capability to define other losses for the
# base loss such as `MSE`, `MAE` and `Huber`. This can be done as follows.

# %%
m = NeuralProphet(
    loss_func="Huber",
    quantiles=qts,
)
metrics = m.fit(df, freq="D")
# Out:
#   0%|          | 0/137 [00:00<?, ?it/s]
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([32, 1, 1])) that is different to the input size (torch.Size([32, 1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([274, 1, 1])) that is different to the input size (torch.Size([274, 1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([20, 1, 1])) that is different to the input size (torch.Size([20, 1, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#   0%|          | 0/137 [00:00<?, ?it/s]
#   0%|          | 0/141 [00:00<?, ?it/s]WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([32, 1, 3])) that is different to the input size (torch.Size([32, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([20, 1, 3])) that is different to the input size (torch.Size([20, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)

# %%
future = m.make_future_dataframe(df, periods=30, n_historic_predictions=100)
forecast = m.predict(df=future)

# %% [markdown]
# ## With Auto-Regression
# Overall uncertainty can be modelled with the AR-Net as well. The only difference is that,
# to plot the forecasts, always a forecast step needs to be specified using the `highlight_nth_step_ahead_of_each_forecast` function. The uncertainty bands are plotted
# for that particular forecast step, since otherwise the plot can look quite cluttered.

# %%
m = NeuralProphet(
    n_lags=5,
    n_forecasts=3,
    quantiles=qts,
)
metrics = m.fit(df, freq="D")
# Out:
#   0%|          | 0/137 [00:00<?, ?it/s]
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([32, 3, 1])) that is different to the input size (torch.Size([32, 3, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([274, 3, 1])) that is different to the input size (torch.Size([274, 3, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([13, 3, 1])) that is different to the input size (torch.Size([13, 3, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#   0%|          | 0/137 [00:00<?, ?it/s]
#   0%|          | 0/141 [00:00<?, ?it/s]WARNING - (py.warnings._showwarnmsg) - /home/kevin/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921: UserWarning: Using a target size (torch.Size([32, 3, 3])) that is different to the input size (torch.Size([32, 3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/kevin/workspace/neuralprophet/neural_prophet_kevin/tutorials/feature-use/uncertainty_estimation_peyton_manning.ipynb Cell 20 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/home/kevin/workspace/neuralprophet/neural_prophet_kevin/tutorials/feature-use/uncertainty_estimation_peyton_manning.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> m = NeuralProphet(
#       <a href='vscode-notebook-cell:/home/kevin/workspace/neuralprophet/neural_prophet_kevin/tutorials/feature-use/uncertainty_estimation_peyton_manning.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a>     n_lags=5,
#       <a href='vscode-notebook-cell:/home/kevin/workspace/neuralprophet/neural_prophet_kevin/tutorials/feature-use/uncertainty_estimation_peyton_manning.ipynb#X25sZmlsZQ%3D%3D?line=2'>3</a>     n_forecasts=3,
#       <a href='vscode-notebook-cell:/home/kevin/workspace/neuralprophet/neural_prophet_kevin/tutorials/feature-use/uncertainty_estimation_peyton_manning.ipynb#X25sZmlsZQ%3D%3D?line=3'>4</a>     quantiles=qts,
#       <a href='vscode-notebook-cell:/home/kevin/workspace/neuralprophet/neural_prophet_kevin/tutorials/feature-use/uncertainty_estimation_peyton_manning.ipynb#X25sZmlsZQ%3D%3D?line=4'>5</a> )
# ----> <a href='vscode-notebook-cell:/home/kevin/workspace/neuralprophet/neural_prophet_kevin/tutorials/feature-use/uncertainty_estimation_peyton_manning.ipynb#X25sZmlsZQ%3D%3D?line=5'>6</a> metrics = m.fit(df, freq="D")
#
# File ~/workspace/neuralprophet/neural_prophet_kevin/neuralprophet/forecaster.py:668, in NeuralProphet.fit(self, df, freq, validation_df, progress, minimal)
#     666         metrics_df = None
#     667     else:
# --> 668         metrics_df = self._train(df, progress=progress)
#     669 else:
#     670     df_val, _, _, _ = df_utils.prep_or_copy_df(validation_df)
#
# File ~/workspace/neuralprophet/neural_prophet_kevin/neuralprophet/forecaster.py:2423, in NeuralProphet._train(self, df, df_val, progress)
#    2421     val_metrics.reset()
#    2422 # run epoch
# -> 2423 epoch_metrics = self._train_epoch(e, loader)
#    2424 # collect metrics
#    2425 if validate:
#
# File ~/workspace/neuralprophet/neural_prophet_kevin/neuralprophet/forecaster.py:2222, in NeuralProphet._train_epoch(self, e, loader)
#    2220     self.scheduler.step()
#    2221     if self.metrics is not None:
# -> 2222         self.metrics.update(
#    2223             predicted=predicted.detach()[:, :, 0],
#    2224             target=targets.detach().squeeze(dim=2),
#    2225             values={"Loss": loss, "RegLoss": reg_loss},
#    2226         )  # compute metrics only for the median quantile (index 0)
#    2227 if self.metrics is not None:
#    2228     return self.metrics.compute(save=True)
#
# File ~/workspace/neuralprophet/neural_prophet_kevin/neuralprophet/metrics.py:83, in MetricsCollection.update(self, predicted, target, values)
#      66 def update(self, predicted, target, values=None):
#      67     """Update all metrics.
#      68
#      69     Parameters
#    (...)
#      81
#      82     """
# ---> 83     self.update_batch(predicted=predicted, target=target)
#      84     if values is not None:
#      85         self.update_values(values=values, num=target.shape[0])
#
# File ~/workspace/neuralprophet/neural_prophet_kevin/neuralprophet/metrics.py:46, in MetricsCollection.update_batch(self, predicted, target)
#      44 """update BatchMetrics"""
#      45 for m in self.batch_metrics:
# ---> 46     m.update(predicted=predicted, target=target)
#
# File ~/workspace/neuralprophet/neural_prophet_kevin/neuralprophet/metrics.py:299, in BatchMetric.update(self, predicted, target, **kwargs)
#     297     predicted = predicted[:, self.specific_column]
#     298     target = target[:, self.specific_column]
# --> 299 avg_value = self._update_batch_value(predicted, target, **kwargs)
#     300 self._sum += avg_value * num
#     301 self._num_examples += num
#
# File ~/workspace/neuralprophet/neural_prophet_kevin/neuralprophet/metrics.py:496, in LossMetric._update_batch_value(self, predicted, target, **kwargs)
#     495 def _update_batch_value(self, predicted, target, **kwargs):
# --> 496     average_loss = torch.mean(self._loss_fn(predicted, target, **kwargs))
#     497     if len(average_loss.shape) != 0:
#     498         raise ValueError("loss_fn did not return the average loss.")
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/modules/loss.py:921, in SmoothL1Loss.forward(self, input, target)
#     920 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 921     return F.smooth_l1_loss(input, target, reduction=self.reduction, beta=self.beta)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/nn/functional.py:3169, in smooth_l1_loss(input, target, size_average, reduce, reduction, beta)
#    3166 if size_average is not None or reduce is not None:
#    3167     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3169 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
#    3170 return torch._C._nn.smooth_l1_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction), beta)
#
# File ~/anaconda3/envs/dev/lib/python3.9/site-packages/torch/functional.py:75, in broadcast_tensors(*tensors)
#      73 if has_torch_function(tensors):
#      74     return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 75 return _VF.broadcast_tensors(tensors)
#
# RuntimeError: The size of tensor a (32) must match the size of tensor b (3) at non-singleton dimension 1

# %%
future = m.make_future_dataframe(df, periods=3, n_historic_predictions=10)
forecast = m.predict(df=future)

# %%
m.highlight_nth_step_ahead_of_each_forecast(2)
fig_last_forec = m.plot_last_forecast(forecast, include_previous_forecasts=3)
fig_forec = m.plot(forecast)
