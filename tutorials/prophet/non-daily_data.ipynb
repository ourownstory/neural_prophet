# %%
# %load_ext rpy2.ipython
# %matplotlib inline

from neuralprophet import Prophet
import pandas as pd
import logging
import warnings

logging.getLogger('prophet').setLevel(logging.ERROR)
logging.getLogger('numexpr').setLevel(logging.ERROR)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Sub-daily data
#
# Prophet can make forecasts for time series with sub-daily observations by passing in a dataframe with timestamps in the `ds` column. The format of the timestamps should be YYYY-MM-DD HH:MM:SS - see the example csv [here](https://github.com/facebook/prophet/blob/main/examples/example_yosemite_temps.csv). When sub-daily data are used, daily seasonality will automatically be fit. Here we fit Prophet to data with 5-minute resolution (daily temperatures at Yosemite):

# %%
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_yosemite_temps.csv')
m = Prophet(changepoint_prior_scale=0.01)
m.fit(df)
future = m.make_future_dataframe(periods=300, freq='H')
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# INFO - (NP.forecaster.__init__) - Using `_prior_scale` is unsupported for regularisation in NeuralProphet, please use the `_reg` args instead.
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 99.995% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as 5T
# INFO - (NP.forecaster.__handle_missing_data) - dropped 12 NAN row in 'y'
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# {'self': <neuralprophet.wrapper.Prophet object at 0x10d8311c0>, 'growth': 'linear', 'changepoints': None, 'n_changepoints': 25, 'changepoints_range': 0.8, 'trend_reg': 0, 'trend_reg_threshold': False, 'yearly_seasonality': 'auto', 'weekly_seasonality': 'auto', 'daily_seasonality': 'auto', 'seasonality_mode': 'additive', 'seasonality_reg': 0, 'n_forecasts': 1, 'n_lags': 0, 'num_hidden_layers': 0, 'd_hidden': None, 'ar_reg': None, 'learning_rate': None, 'epochs': None, 'batch_size': None, 'loss_func': 'Huber', 'optimizer': 'AdamW', 'newer_samples_weight': 2, 'newer_samples_start': 0.0, 'uncertainty_method': 'auto', 'prediction_interval': 0.8, 'quantiles': None, 'impute_missing': True, 'impute_linear': 10, 'impute_rolling': 10, 'drop_missing': False, 'collect_metrics': True, 'normalize': 'auto', 'global_normalization': False, 'global_time_normalization': True, 'unknown_data_normalization': False}
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 64
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 88
#   0%|          | 0/156 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 4.29E-02, min: 6.22E-01
#   0%|          | 0/156 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.75E-02, min: 6.22E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 5.44E-02
# Epoch[88/88]: 100%|██████████| 88/88 [00:27<00:00,  3.26it/s, SmoothL1Loss=0.00316, MAE=2.97, RMSE=4.29, Loss=0.00336, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 99.995% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - 5T
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 99.995% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - 5T
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 99.995% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - 5T
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# WARNING - (NP.forecaster.plot) - The attributes `uncertainty`, `plot_cap` and `include_legend` are not supported by NeuralProphet

# %% [markdown]
# The daily seasonality will show up in the components plot:

# %%
fig = m.plot_components(fcst)
# Out:
# WARNING - (NP.forecaster.plot_components) - The attributes `uncertainty`, `plot_cap`, `weekly_start` and `yearly_start` are not supported by NeuralProphet

# %% [markdown]
# ## Data with regular gaps
#
# Suppose the dataset above only had observations from 12a to 6a:

# %%
df2 = df.copy()
df2['ds'] = pd.to_datetime(df2['ds'])
df2 = df2[df2['ds'].dt.hour < 6]
m = Prophet()
m.fit(df2)
future = m.make_future_dataframe(periods=300, freq='H')
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.59% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as 5T
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling yearly seasonality. Run NeuralProphet with yearly_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 32
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 125
#   0%|          | 0/141 [00:00<?, ?it/s]
# {'self': <neuralprophet.wrapper.Prophet object at 0x166490e20>, 'growth': 'linear', 'changepoints': None, 'n_changepoints': 25, 'changepoints_range': 0.8, 'trend_reg': 0, 'trend_reg_threshold': False, 'yearly_seasonality': 'auto', 'weekly_seasonality': 'auto', 'daily_seasonality': 'auto', 'seasonality_mode': 'additive', 'seasonality_reg': 0, 'n_forecasts': 1, 'n_lags': 0, 'num_hidden_layers': 0, 'd_hidden': None, 'ar_reg': None, 'learning_rate': None, 'epochs': None, 'batch_size': None, 'loss_func': 'Huber', 'optimizer': 'AdamW', 'newer_samples_weight': 2, 'newer_samples_start': 0.0, 'uncertainty_method': 'auto', 'prediction_interval': 0.8, 'quantiles': None, 'impute_missing': True, 'impute_linear': 10, 'impute_rolling': 10, 'drop_missing': False, 'collect_metrics': True, 'normalize': 'auto', 'global_normalization': False, 'global_time_normalization': True, 'unknown_data_normalization': False}
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.92E-02, min: 4.18E-01
#   0%|          | 0/141 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 4.54E-02, min: 7.56E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 5.62E-02
# Epoch[125/125]: 100%|██████████| 125/125 [00:16<00:00,  7.45it/s, SmoothL1Loss=0.00239, MAE=1.93, RMSE=2.78, Loss=0.00274, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.59% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - 5T
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.675% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - 5T
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.675% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - 5T
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# WARNING - (NP.forecaster.plot) - The attributes `uncertainty`, `plot_cap` and `include_legend` are not supported by NeuralProphet

# %% [markdown]
# The forecast seems quite poor, with much larger fluctuations in the future than were seen in the history. The issue here is that we have fit a daily cycle to a time series that only has data for part of the day (12a to 6a). The daily seasonality is thus unconstrained for the remainder of the day and is not estimated well. The solution is to only make predictions for the time windows for which there are historical data. Here, that means to limit the `future` dataframe to have times from 12a to 6a:

# %%
future2 = future.copy()
future2 = future2[future2['ds'].dt.hour < 6]
fcst = m.predict(future2)
fig = m.plot(fcst)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.594% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - 5T
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.594% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - 5T
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# WARNING - (NP.forecaster.plot) - The attributes `uncertainty`, `plot_cap` and `include_legend` are not supported by NeuralProphet

# %% [markdown]
# The same principle applies to other datasets with regular gaps in the data. For example, if the history contains only weekdays, then predictions should only be made for weekdays since the weekly seasonality will not be well estimated for the weekends.
#
# ## Monthly data
#
# You can use Prophet to fit monthly data. However, the underlying model is continuous-time, which means that you can get strange results if you fit the model to monthly data and then ask for daily forecasts. Here we forecast US retail sales volume for the next 10 years:

# %%
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_retail_sales.csv')
m = Prophet(seasonality_mode='multiplicative')
m.fit(df)
future = m.make_future_dataframe(periods=3652)
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.126% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as MS
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 305
#   0%|          | 0/114 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.76E-02, min: 1.36E-01
#   0%|          | 0/114 [00:00<?, ?it/s]
# {'self': <neuralprophet.wrapper.Prophet object at 0x166d5c820>, 'growth': 'linear', 'changepoints': None, 'n_changepoints': 25, 'changepoints_range': 0.8, 'trend_reg': 0, 'trend_reg_threshold': False, 'yearly_seasonality': 'auto', 'weekly_seasonality': 'auto', 'daily_seasonality': 'auto', 'seasonality_mode': 'multiplicative', 'seasonality_reg': 0, 'n_forecasts': 1, 'n_lags': 0, 'num_hidden_layers': 0, 'd_hidden': None, 'ar_reg': None, 'learning_rate': None, 'epochs': None, 'batch_size': None, 'loss_func': 'Huber', 'optimizer': 'AdamW', 'newer_samples_weight': 2, 'newer_samples_start': 0.0, 'uncertainty_method': 'auto', 'prediction_interval': 0.8, 'quantiles': None, 'impute_missing': True, 'impute_linear': 10, 'impute_rolling': 10, 'drop_missing': False, 'collect_metrics': True, 'normalize': 'auto', 'global_normalization': False, 'global_time_normalization': True, 'unknown_data_normalization': False}
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 4.52E-02, min: 1.96E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 5.54E-02
# Epoch[305/305]: 100%|██████████| 305/305 [00:05<00:00, 55.69it/s, SmoothL1Loss=0.000305, MAE=5.32e+3, RMSE=7.08e+3, Loss=0.000301, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.126% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - MS
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# /Users/karl/git/neural_prophet/tutorials/prophet/non-daily_data.ipynb Cell 11 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/karl/git/neural_prophet/tutorials/prophet/non-daily_data.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> m = Prophet(seasonality_mode='multiplicative')
#       <a href='vscode-notebook-cell:/Users/karl/git/neural_prophet/tutorials/prophet/non-daily_data.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> m.fit(df)
# ----> <a href='vscode-notebook-cell:/Users/karl/git/neural_prophet/tutorials/prophet/non-daily_data.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> future = m.make_future_dataframe(periods=3652)
#       <a href='vscode-notebook-cell:/Users/karl/git/neural_prophet/tutorials/prophet/non-daily_data.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> fcst = m.predict(future)
#       <a href='vscode-notebook-cell:/Users/karl/git/neural_prophet/tutorials/prophet/non-daily_data.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> fig = m.plot(fcst)
#
# File ~/git/neural_prophet/neuralprophet/wrapper.py:265, in Prophet.make_future_dataframe(self, periods, freq, include_history, **kwargs)
#     257     df_future = super(Prophet, self).make_future_dataframe(
#     258         df=self.history,
#     259         events_df=self.events_df,
#    (...)
#     262         **kwargs,
#     263     )
#     264 else:
# --> 265     df_future = super(Prophet, self).make_future_dataframe(
#     266         df=self.history, periods=periods, n_historic_predictions=include_history, **kwargs
#     267     )
#     268 return df_future
#
# File ~/git/neural_prophet/neuralprophet/forecaster.py:1221, in NeuralProphet.make_future_dataframe(self, df, events_df, regressors_df, periods, n_historic_predictions)
#    1219 df_future_dataframe = pd.DataFrame()
#    1220 for df_name, df_i in df.groupby("ID"):
# -> 1221     df_aux = self._make_future_dataframe(
#    1222         df=df_i,
#    1223         events_df=events_dict[df_name],
#    1224         regressors_df=regressors_dict[df_name],
#    1225         periods=periods,
#    1226         n_historic_predictions=n_historic_predictions,
#    1227     )
#    1228     df_aux["ID"] = df_name
#    1229     df_future_dataframe = pd.concat((df_future_dataframe, df_aux), ignore_index=True)
#
# File ~/git/neural_prophet/neuralprophet/forecaster.py:2642, in NeuralProphet._make_future_dataframe(self, df, events_df, regressors_df, periods, n_historic_predictions)
#    2637         log.warning(
#    2638             "Number of forecast steps is defined by n_forecasts. " "Adjusted to {}.".format(self.n_forecasts)
#    2639         )
#    2641 if periods > 0:
# -> 2642     future_df = df_utils.make_future_df(
#    2643         df_columns=df.columns,
#    2644         last_date=last_date,
#    2645         periods=periods,
#    2646         freq=self.data_freq,
#    2647         events_config=self.events_config,
#    2648         events_df=events_df,
#    2649         regressor_config=self.regressors_config,
#    2650         regressors_df=regressors_df,
#    2651     )
#    2652     if len(df) > 0:
#    2653         df = pd.concat([df, future_df])
#
# File ~/git/neural_prophet/neuralprophet/df_utils.py:965, in make_future_df(df_columns, last_date, periods, freq, events_config, events_df, regressor_config, regressors_df)
#     935 def make_future_df(
#     936     df_columns, last_date, periods, freq, events_config=None, events_df=None, regressor_config=None, regressors_df=None
#     937 ):
#     938     """Extends df periods number steps into future.
#     939
#     940     Parameters
#    (...)
#     963             input df with ``ds`` extended into future, and ``y`` set to None
#     964     """
# --> 965     future_dates = pd.date_range(start=last_date, periods=periods + 1, freq=freq)  # An extra in case we include start
#     966     future_dates = future_dates[future_dates > last_date]  # Drop start if equals last_date
#     967     future_dates = future_dates[:periods]  # Return correct number of periods
#
# File ~/git/neural_prophet/venv/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py:1070, in date_range(start, end, periods, freq, tz, normalize, name, closed, inclusive, **kwargs)
#    1067 if freq is None and com.any_none(periods, start, end):
#    1068     freq = "D"
# -> 1070 dtarr = DatetimeArray._generate_range(
#    1071     start=start,
#    1072     end=end,
#    1073     periods=periods,
#    1074     freq=freq,
#    1075     tz=tz,
#    1076     normalize=normalize,
#    1077     inclusive=inclusive,
#    1078     **kwargs,
#    1079 )
#    1080 return DatetimeIndex._simple_new(dtarr, name=name)
#
# File ~/git/neural_prophet/venv/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:448, in DatetimeArray._generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, inclusive)
#     446 else:
#     447     xdr = generate_range(start=start, end=end, periods=periods, offset=freq)
# --> 448     values = np.array([x.value for x in xdr], dtype=np.int64)
#     450 _tz = start.tz if start is not None else end.tz
#     451 values = values.view("M8[ns]")
#
# File ~/git/neural_prophet/venv/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:448, in <listcomp>(.0)
#     446 else:
#     447     xdr = generate_range(start=start, end=end, periods=periods, offset=freq)
# --> 448     values = np.array([x.value for x in xdr], dtype=np.int64)
#     450 _tz = start.tz if start is not None else end.tz
#     451 values = values.view("M8[ns]")
#
# File ~/git/neural_prophet/venv/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:2563, in generate_range(start, end, periods, offset)
#    2560     periods = 0
#    2562 if end is None:
# -> 2563     end = start + (periods - 1) * offset
#    2565 if start is None:
#    2566     start = end - (periods - 1) * offset
#
# File pandas/_libs/tslibs/offsets.pyx:444, in pandas._libs.tslibs.offsets.BaseOffset.__add__()
#
# File pandas/_libs/tslibs/offsets.pyx:450, in pandas._libs.tslibs.offsets.BaseOffset.__add__()
#
# File pandas/_libs/tslibs/offsets.pyx:180, in pandas._libs.tslibs.offsets.apply_wraps.wrapper()
#
# File pandas/_libs/tslibs/offsets.pyx:2222, in pandas._libs.tslibs.offsets.MonthOffset._apply()
#
# File pandas/_libs/tslibs/offsets.pyx:3990, in pandas._libs.tslibs.offsets.shift_month()
#
# File pandas/_libs/tslibs/timestamps.pyx:2033, in pandas._libs.tslibs.timestamps.Timestamp.replace()
#
# File pandas/_libs/tslibs/conversion.pyx:517, in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# File pandas/_libs/tslibs/np_datetime.pyx:120, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 2320-09-01 00:00:00

# %% [markdown]
# This is the same issue from above where the dataset has regular gaps. When we fit the yearly seasonality, it only has data for the first of each month and the seasonality components for the remaining days are unidentifiable and overfit. This can be clearly seen by doing MCMC to see uncertainty in the seasonality:

# %%
m = Prophet(seasonality_mode='multiplicative', mcmc_samples=300)
m.fit(df, show_progress=False)
fcst = m.predict(future)
fig = m.plot_components(fcst)
# Out:
# INFO - (NP.forecaster.__init__) - Providing the number of samples for Bayesian inference or Uncertainty estimation is not required in NeuralProphet.
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.126% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as MS
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 305
#   0%|          | 0/114 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 3.13E-02, min: 9.41E-02
#   0%|          | 0/114 [00:00<?, ?it/s]
# {'self': <neuralprophet.wrapper.Prophet object at 0x168ff3b20>, 'growth': 'linear', 'changepoints': None, 'n_changepoints': 25, 'changepoints_range': 0.8, 'trend_reg': 0, 'trend_reg_threshold': False, 'yearly_seasonality': 'auto', 'weekly_seasonality': 'auto', 'daily_seasonality': 'auto', 'seasonality_mode': 'multiplicative', 'seasonality_reg': 0, 'n_forecasts': 1, 'n_lags': 0, 'num_hidden_layers': 0, 'd_hidden': None, 'ar_reg': None, 'learning_rate': None, 'epochs': None, 'batch_size': None, 'loss_func': 'Huber', 'optimizer': 'AdamW', 'newer_samples_weight': 2, 'newer_samples_start': 0.0, 'uncertainty_method': 'auto', 'prediction_interval': 0.8, 'quantiles': None, 'impute_missing': True, 'impute_linear': 10, 'impute_rolling': 10, 'drop_missing': False, 'collect_metrics': True, 'normalize': 'auto', 'global_normalization': False, 'global_time_normalization': True, 'unknown_data_normalization': False}
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 2.61E-02, min: 7.83E-02
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 4.34E-02
# Epoch[305/305]: 100%|██████████| 305/305 [00:05<00:00, 54.53it/s, SmoothL1Loss=0.000316, MAE=5.43e+3, RMSE=7.21e+3, Loss=0.000311, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.675% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency MS is different than major frequency 5T
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.675% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency MS is different than major frequency 5T
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# WARNING - (NP.forecaster.plot_components) - The attributes `uncertainty`, `plot_cap`, `weekly_start` and `yearly_start` are not supported by NeuralProphet

# %%
m = Prophet(seasonality_mode='multiplicative', mcmc_samples=300)
m.fit(df)
fcst = m.predict(future)
fig = m.plot_components(fcst)
# Out:
# INFO - (NP.forecaster.__init__) - Providing the number of samples for Bayesian inference or Uncertainty estimation is not required in NeuralProphet.
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.126% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as MS
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 305
#   0%|          | 0/114 [00:00<?, ?it/s]
# {'self': <neuralprophet.wrapper.Prophet object at 0x1690e3520>, 'growth': 'linear', 'changepoints': None, 'n_changepoints': 25, 'changepoints_range': 0.8, 'trend_reg': 0, 'trend_reg_threshold': False, 'yearly_seasonality': 'auto', 'weekly_seasonality': 'auto', 'daily_seasonality': 'auto', 'seasonality_mode': 'multiplicative', 'seasonality_reg': 0, 'n_forecasts': 1, 'n_lags': 0, 'num_hidden_layers': 0, 'd_hidden': None, 'ar_reg': None, 'learning_rate': None, 'epochs': None, 'batch_size': None, 'loss_func': 'Huber', 'optimizer': 'AdamW', 'newer_samples_weight': 2, 'newer_samples_start': 0.0, 'uncertainty_method': 'auto', 'prediction_interval': 0.8, 'quantiles': None, 'impute_missing': True, 'impute_linear': 10, 'impute_rolling': 10, 'drop_missing': False, 'collect_metrics': True, 'normalize': 'auto', 'global_normalization': False, 'global_time_normalization': True, 'unknown_data_normalization': False}
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 9.41E-02, min: 3.40E-01
#   0%|          | 0/114 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 9.41E-02, min: 3.40E-01
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 9.60E-02
# Epoch[305/305]: 100%|██████████| 305/305 [00:08<00:00, 38.02it/s, SmoothL1Loss=0.000306, MAE=5.3e+3, RMSE=7.07e+3, Loss=0.000303, RegLoss=0]
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.675% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency MS is different than major frequency 5T
# INFO - (NP.df_utils._infer_frequency) - Major frequency 5T corresponds to 98.675% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency MS is different than major frequency 5T
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# WARNING - (NP.forecaster.plot_components) - The attributes `uncertainty`, `plot_cap`, `weekly_start` and `yearly_start` are not supported by NeuralProphet

# %% [markdown]
# The seasonality has low uncertainty at the start of each month where there are data points, but has very high posterior variance in between. When fitting Prophet to monthly data, only make monthly forecasts, which can be done by passing the frequency into `make_future_dataframe`:

# %%
future = m.make_future_dataframe(periods=120, freq='MS')
fcst = m.predict(future)
fig = m.plot(fcst)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.126% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - MS
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.283% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - MS
# INFO - (NP.df_utils._infer_frequency) - Major frequency MS corresponds to 91.283% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - MS
# INFO - (NP.df_utils.return_df_in_original_format) - Returning df with no ID column
# WARNING - (NP.forecaster.plot) - The attributes `uncertainty`, `plot_cap` and `include_legend` are not supported by NeuralProphet

# %% [markdown]
# In Python, the frequency can be anything from the pandas list of frequency strings here: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases . Note that `MS` used here is month-start, meaning the data point is placed on the start of each month.
#
# In monthly data, yearly seasonality can also be modeled with binary extra regressors. In particular, the model can use 12 extra regressors like `is_jan`, `is_feb`, etc. where `is_jan` is 1 if the date is in Jan and 0 otherwise. This approach would avoid the within-month unidentifiability seen above. Be sure to use `yearly_seasonality=False` if monthly extra regressors are being added.

# %% [markdown]
# ## Holidays with aggregated data
#
# Holiday effects are applied to the particular date on which the holiday was specified. With data that has been aggregated to weekly or monthly frequency, holidays that don't fall on the particular date used in the data will be ignored: for example, a Monday holiday in a weekly time series where each data point is on a Sunday. To include holiday effects in the model, the holiday will need to be moved to the date in the history dataframe for which the effect is desired. Note that with weekly or monthly aggregated data, many holiday effects will be well-captured by the yearly seasonality, so added holidays may only be necessary for holidays that occur in different weeks throughout the time series.
