# %%
try:
    # it already installed dependencies
    from torchsummary import summary
    from torchviz import make_dot
except:
    # install graphviz on system
    import platform

    if "Darwin" == platform.system():
        # !brew install graphviz
    elif "Linux" == platform.system():
        # !sudo apt install graphviz
    else:
        print("go to  https://www.graphviz.org/download/")
    # Next we need to install the following dependencies:
    # !pip install torchsummary
    # !pip install torch-summary
    # !pip install torchviz
    # !pip install graphviz
    # import
    from torchsummary import summary
    from torchviz import make_dot

# %%
if "google.colab" in str(get_ipython()):
    # !pip install git+https://github.com/ourownstory/neural_prophet.git # may take a while
    #!pip install neuralprophet # much faster, but may not have the latest upgrades/bugfixes

import pandas as pd
from neuralprophet import NeuralProphet, set_log_level
from neuralprophet import set_random_seed

set_random_seed(10)
set_log_level("ERROR", "INFO")
# Out:
# NOTE: Redirects are currently not supported in Windows or MacOs.
# /Users/alfonsogarciadecorral/Desktop/code/neural_prophet/env/lib/python3.8/site-packages/plotly_resampler/aggregation/aggregators.py:24: UserWarning: Could not import lttbc; will use a (slower) python alternative.
#   warnings.warn("Could not import lttbc; will use a (slower) python alternative.")

# %%
import pandas as pd

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ourownstory/neural_prophet/blob/main/tutorials/feature-use/global_local_modeling.ipynb)

# %% [markdown]
# # Global Local Model
# When fitting a single forecasting model with shared weights using a dataset composed of many time series, we can achieve what is known as a **global model**. It is specially useful in cases in which a single time series may not reflect the entire time series dynamics. In addition, global models provide better generalization and model size saving. In this notebook, we will build a global model using data from the hourly load of the ERCOT region.
#
# When many time series share only "some behaviour" we will need a **global local model**. In the following notebook we will see an example of time series sharing behaviour/weights on all the components except from the trend and seasonality. Therefore, we will also build a global local model using data from the hourly load of the ERCOT region.
#
# This notebook is an adaptation of `global_modeling.ipynb`.

# %% [markdown]
# First, we load the data:

# %%
data_location = "https://raw.githubusercontent.com/ourownstory/neuralprophet-data/main/datasets/"
df_ercot = pd.read_csv(data_location + "multivariate/load_ercot_regions.csv")
df_ercot.head()
# Out:
#                     ds    COAST    EAST  FAR_WEST   NORTH  NORTH_C  SOUTHERN  \
# 0  2004-01-01 01:00:00  7225.09  877.79   1044.89  745.79  7124.21   1660.45
# 1  2004-01-01 02:00:00  6994.25  850.75   1032.04  721.34  6854.58   1603.52
# 2  2004-01-01 03:00:00  6717.42  831.63   1021.10  699.70  6639.48   1527.99
# 3  2004-01-01 04:00:00  6554.27  823.56   1015.41  691.84  6492.39   1473.89
# 4  2004-01-01 05:00:00  6511.19  823.38   1009.74  686.76  6452.26   1462.76
#
#    SOUTH_C    WEST
# 0  3639.12  654.61
# 1  3495.16  639.88
# 2  3322.70  623.42
# 3  3201.72  613.49
# 4  3163.74  613.32

# %% [markdown]
# We extract the name of the regions which will be later used in the model creation.

# %%
regions = list(df_ercot)[1:]

# %%
list(set(df_ercot.ds))[0]
# Out:
# '2005-11-27 09:00:00'

# %% [markdown]
# Global models can be enabled when the `df` input of the function has an additional column 'ID', which identifies the different time-series (besides the typical column 'ds', which has the timestamps, and column 'y', which contains the observed values of the time series). We select data from a three-year interval in our example (from 2004 to 2007).

# %%
df_global = pd.DataFrame()
for col in regions:
    aux = df_ercot[["ds", col]].copy(deep=True)  # select column associated with region
    aux = aux.iloc[:26301, :].copy(deep=True)  # selects data up to 26301 row (2004 to 2007 time stamps)
    aux = aux.rename(columns={col: "y"})  # rename column of data to 'y' which is compatible with Neural Prophet
    aux["ID"] = col
    df_global = pd.concat((df_global, aux))

# %% [markdown]
# We will modify one time series trend and one time series seasonality

# %%
import numpy as np

df_global["y"] = (
    np.where(df_global["ID"] == "COAST", -df_global["y"], df_global["y"])
    + 2 * df_global[df_global["ID"] == "COAST"].mean().y
)
df_global["y"] = np.where(df_global["ID"] == "NORTH", df_global["y"] + 0.1 * df_global.index, df_global["y"])

df_global[df_global["ID"] == "NORTH"].plot()
df_global[df_global["ID"] == "COAST"].plot()
# Out:
# WARNING - (py.warnings._showwarnmsg) - /var/folders/g5/gjgtytcx0zb3tysnmlfdy0jr0000gn/T/ipykernel_7864/3026129503.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   + 2 * df_global[df_global["ID"] == "COAST"].mean().y
# <AxesSubplot:>

# %%
df_local = df_global[df_global["ID"] == "COAST"]
df_local = df_local[["ds", "y"]]

# %%
m = NeuralProphet()
df_train, df_test = m.split_df(df_global, valid_p=0.33, local_split=True)

# %% [markdown]
# ## Global Modeling

# %% [markdown]
# **Remark:**
# - Training a time series only with trend and seasonality components can result in poor performance. The following example is used just to show the new local modelling of multiple time series functionallity.

# %% [markdown]
# ### DIFFERENT SEASONALITY MODELLING

# %%
m = NeuralProphet(
    n_forecasts=1,
    epochs=1,
    batch_size=32,
    trend_global_local="local",
)

m.add_seasonality(period=30, fourier_order=8, name="monthly", global_local="local")
train_df, test_df = m.split_df(df_global, valid_p=0.33, local_split=True)
m.fit(train_df)
future = m.make_future_dataframe(test_df, n_historic_predictions=True)
forecast = m.predict(future)
metrics = m.test(test_df)
forecast_trend = m.predict_trend(test_df)
forecast_seasonal_componets = m.predict_seasonal_components(test_df)
# Out:
# ConfigSeasonality(mode='additive', computation='fourier', reg_lambda=0, yearly_arg='auto', weekly_arg='auto', daily_arg='auto', periods=OrderedDict([('yearly', Season(resolution=6, period=365.25, arg='auto', condition_name=None, global_local='global')), ('weekly', Season(resolution=3, period=7, arg='auto', condition_name=None, global_local='global')), ('daily', Season(resolution=6, period=1, arg='auto', condition_name=None, global_local='global')), ('monthly', Season(resolution=8, period=30, arg='custom', condition_name=None, global_local='local'))]), global_local='glocal', yearly_global_local='auto', weekly_global_local='auto', daily_global_local='auto', condition_name=None)
# Finding best initial lr:   0%|          | 0/278 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]
# Predicting: 4406it [00:00, ?it/s]
# Predicting: 4406it [00:00, ?it/s]
# Predicting: 4406it [00:00, ?it/s]
# Predicting: 4406it [00:00, ?it/s]
# Predicting: 4406it [00:00, ?it/s]
# Predicting: 4406it [00:00, ?it/s]
# Predicting: 4406it [00:00, ?it/s]
# Predicting: 4406it [00:00, ?it/s]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         Loss_test         │    0.1260015219449997     │
# │       RegLoss_test        │            0.0            │
# └───────────────────────────┴───────────────────────────┘

# %%
fig = m.plot(forecast[forecast["ID"] == "NORTH"])
fig_param = m.plot_parameters(df_name="NORTH")

# %%
fig = m.plot(forecast[forecast["ID"] == "COAST"])
fig_param = m.plot_parameters(df_name="COAST")

# %%
fig = m.plot(forecast[forecast["ID"] == "EAST"])
fig_param = m.plot_parameters(df_name="EAST")

# %%
test_metrics_global = m.test(df_test)
test_metrics_global
# Out:
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         Loss_test         │    0.04340827465057373    │
# │       RegLoss_test        │            0.0            │
# └───────────────────────────┴───────────────────────────┘
#    Loss_test  RegLoss_test
# 0   0.043408           0.0

# %% [markdown]
# ### GLOCAL TREND

# %% [markdown]
# We will repeat the process above, but for local modelling of trend and seasonality.

# %%
m = NeuralProphet(
    trend_global_local="local",
    #     season_global_local="local",
    glocal_trend_reg=3,
    changepoints_range=0.8,
    epochs=2,
    trend_reg=1,
)

# %%
# Out:
# 1

# %%
metrics = m.fit(df_train, freq="H")
# Out:
# Finding best initial lr:   0%|          | 0/278 [00:00<?, ?it/s]
# Training: 0it [00:00, ?it/s]

# %%
future = m.make_future_dataframe(df_test, n_historic_predictions=True)
forecast = m.predict(future)
# Out:
# Predicting: 1102it [00:00, ?it/s]
# Predicting: 1102it [00:00, ?it/s]
# Predicting: 1102it [00:00, ?it/s]
# Predicting: 1102it [00:00, ?it/s]
# Predicting: 1102it [00:00, ?it/s]
# Predicting: 1102it [00:00, ?it/s]
# Predicting: 1102it [00:00, ?it/s]
# Predicting: 1102it [00:00, ?it/s]

# %%
fig = m.plot(forecast[forecast["ID"] == "NORTH"])
fig_param = m.plot_parameters(df_name="NORTH")

# %%
fig = m.plot(forecast[forecast["ID"] == "COAST"])
fig_param = m.plot_parameters(df_name="COAST")

# %%
fig = m.plot(forecast[forecast["ID"] == "EAST"])
fig_param = m.plot_parameters(df_name="EAST")

# %%
test_metrics_local = m.test(df_test)
test_metrics_local
# Out:
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         Loss_test         │    0.04433564841747284    │
# │       RegLoss_test        │            0.0            │
# └───────────────────────────┴───────────────────────────┘
#    Loss_test  RegLoss_test
# 0   0.044336           0.0

# %%
future = m.make_future_dataframe(df_test)
forecast = m.predict(future)
metrics = m.test(df_test)
forecast_trend = m.predict_trend(df_test)
forecast_seasonal_componets = m.predict_seasonal_components(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 future = m.make_future_dataframe(df_test)
# ----> 2 forecast = m.predict(future)
#       3 metrics = m.test(df_test)
#       4 forecast_trend = m.predict_trend(df_test)
#
# File ~/Desktop/code/neural_prophet/neuralprophet/forecaster.py:831, in NeuralProphet.predict(self, df, decompose, raw)
#     829 df, received_ID_col, received_single_time_series, _ = df_utils.prep_or_copy_df(df)
#     830 # to get all forecasteable values with df given, maybe extend into future:
# --> 831 df, periods_added = self._maybe_extend_df(df)
#     832 df = self._prepare_dataframe_to_predict(df)
#     833 # normalize
#
# File ~/Desktop/code/neural_prophet/neuralprophet/forecaster.py:2773, in NeuralProphet._maybe_extend_df(self, df)
#    2771 extended_df = pd.DataFrame()
#    2772 for df_name, df_i in df.groupby("ID"):
# -> 2773     _ = df_utils.infer_frequency(df_i, n_lags=self.max_lags, freq=self.data_freq)
#    2774     # to get all forecasteable values with df given, maybe extend into future:
#    2775     periods_add[df_name] = self._get_maybe_extend_periods(df_i)
#
# File ~/Desktop/code/neural_prophet/neuralprophet/df_utils.py:1324, in infer_frequency(df, freq, n_lags, min_freq_percentage)
#    1322 freq_df = list()
#    1323 for df_name, df_i in df.groupby("ID"):
# -> 1324     freq_df.append(_infer_frequency(df_i, freq, min_freq_percentage))
#    1325 if len(set(freq_df)) != 1 and n_lags > 0:
#    1326     raise ValueError(
#    1327         "One or more dataframes present different major frequencies, please make sure all dataframes present the same major frequency for auto-regression"
#    1328     )
#
# File ~/Desktop/code/neural_prophet/neuralprophet/df_utils.py:1252, in _infer_frequency(df, freq, min_freq_percentage)
#    1250     dominant_freq_percentage = distribution.max() / len(df["ds"])
#    1251     num_freq = frequencies[np.argmax(distribution)]  # get value of most common diff
# -> 1252     inferred_freq = convert_num_to_str_freq(num_freq, df["ds"].iloc[0])
#    1254 log.info(
#    1255     f"Major frequency {inferred_freq} corresponds to {np.round(dominant_freq_percentage * 100, 3)}% of the data."
#    1256 )
#    1257 ideal_freq_exists = True if dominant_freq_percentage >= min_freq_percentage else False
#
# File ~/Desktop/code/neural_prophet/neuralprophet/df_utils.py:1159, in convert_num_to_str_freq(freq_num, initial_time_stamp)
#    1144 def convert_num_to_str_freq(freq_num, initial_time_stamp):
#    1145     """Convert numeric frequencies into frequency tags
#    1146
#    1147     Parameters
#    (...)
#    1157             frequency tag
#    1158     """
# -> 1159     aux_ts = pd.date_range(initial_time_stamp, periods=100, freq=pd.to_timedelta(freq_num))
#    1160     freq_str = pd.infer_freq(aux_ts)
#    1161     return freq_str
#
# File ~/Desktop/code/neural_prophet/env/lib/python3.8/site-packages/pandas/core/indexes/datetimes.py:1070, in date_range(start, end, periods, freq, tz, normalize, name, closed, inclusive, **kwargs)
#    1067 if freq is None and com.any_none(periods, start, end):
#    1068     freq = "D"
# -> 1070 dtarr = DatetimeArray._generate_range(
#    1071     start=start,
#    1072     end=end,
#    1073     periods=periods,
#    1074     freq=freq,
#    1075     tz=tz,
#    1076     normalize=normalize,
#    1077     inclusive=inclusive,
#    1078     **kwargs,
#    1079 )
#    1080 return DatetimeIndex._simple_new(dtarr, name=name)
#
# File ~/Desktop/code/neural_prophet/env/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py:409, in DatetimeArray._generate_range(cls, start, end, periods, freq, tz, normalize, ambiguous, nonexistent, inclusive)
#     404 if com.count_not_none(start, end, periods, freq) != 3:
#     405     raise ValueError(
#     406         "Of the four parameters: start, end, periods, "
#     407         "and freq, exactly three must be specified"
#     408     )
# --> 409 freq = to_offset(freq)
#     411 if start is not None:
#     412     start = Timestamp(start)
#
# File pandas/_libs/tslibs/offsets.pyx:3580, in pandas._libs.tslibs.offsets.to_offset()
#
# File pandas/_libs/tslibs/offsets.pyx:3682, in pandas._libs.tslibs.offsets.to_offset()
#
# ValueError: Invalid frequency: NaT

# %%
fig = make_dot(m.model.train_epoch_prediction, params=dict(m.model.named_parameters()))
# fig_glob.render(filename='img/fig_glob')
display(fig)
