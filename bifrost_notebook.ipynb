# %%
import pandas as pd

# %%
from code.bifrost import Bifrost

# %%
# df = pd.read_csv('data/example_air_passengers.csv')
df = pd.read_csv('data/example_wp_log_peyton_manning.csv')
df.shape
# Out:
# (2905, 2)

# %% [markdown]
# ## Estimate Model Accuracy

# %%
# print(df.shape)
# seasonality = 12
# train_frac = 0.9
# train_num = int((train_frac * df.shape[0]) //seasonality *seasonality)
# print(train_num)
# df_train = df.copy(deep=True).iloc[:train_num]
# df_val = df.copy(deep=True).iloc[train_num:]

# %%
# m = Bifrost(
#     n_lags=seasonality, 
#     n_forecasts=1, 
#     n_trend=1, 
#     normalize=True, 
#     verbose=True,
# )
# m.fit(df_train)

# %%
# m.test(df_val)

# %% [markdown]
# ##  Fit and Plot

# %%
m_trend = Bifrost(n_forecasts=1, n_lags=0, n_changepoints=20, verbose=False)
m_trend.fit(df)
forecast_trend = m_trend.predict_history(forecast_lag=1)

# %%
fig = m_trend.plot(forecast_trend)

# %%
fig1 = m_trend.plot_components(forecast_trend)

# %%
### with lags

# %%
m = Bifrost(n_forecasts=30, n_lags=60, n_changepoints=50, verbose=True)
m.fit(df)
# Out:
# model_complexity 47.35823250391718
# TimeNet(
#   (ar): Linear(in_features=60, out_features=30, bias=False)
# )
# AttrDict({'t_start': Timestamp('2007-12-10 00:00:00'), 't_scale': Timedelta('2963 days 00:00:00'), 'y_shift': 8.138957937650906, 'y_scale': 0.8458113663030432})
# time shape:  (2816, 30)
# lags shape:  (2816, 60)
# 1. Epoch Avg Loss:       2.21
# 2. Epoch Avg Loss:       1.05
# 3. Epoch Avg Loss:       0.84
# 4. Epoch Avg Loss:       0.72
# 5. Epoch Avg Loss:       0.66
# 6. Epoch Avg Loss:       0.63
# 7. Epoch Avg Loss:       0.60
# 8. Epoch Avg Loss:       0.58
# 9. Epoch Avg Loss:       0.57
# 10. Epoch Avg Loss:       0.56
# 11. Epoch Avg Loss:       0.55
# 12. Epoch Avg Loss:       0.54
# 13. Epoch Avg Loss:       0.54
# 14. Epoch Avg Loss:       0.53
# 15. Epoch Avg Loss:       0.53
# 16. Epoch Avg Loss:       0.53
# 17. Epoch Avg Loss:       0.52
# 18. Epoch Avg Loss:       0.52
# 19. Epoch Avg Loss:       0.52
# 20. Epoch Avg Loss:       0.52
# 21. Epoch Avg Loss:       0.52
# 22. Epoch Avg Loss:       0.52
# 23. Epoch Avg Loss:       0.52
# 24. Epoch Avg Loss:       0.51
# 25. Epoch Avg Loss:       0.51
# 26. Epoch Avg Loss:       0.51
# 27. Epoch Avg Loss:       0.51
# 28. Epoch Avg Loss:       0.51
# 29. Epoch Avg Loss:       0.51
# 30. Epoch Avg Loss:       0.51
# 31. Epoch Avg Loss:       0.51
# 32. Epoch Avg Loss:       0.51
# 33. Epoch Avg Loss:       0.51
# 34. Epoch Avg Loss:       0.51
# 35. Epoch Avg Loss:       0.51
# 36. Epoch Avg Loss:       0.51
# 37. Epoch Avg Loss:       0.51
# 38. Epoch Avg Loss:       0.51
# 39. Epoch Avg Loss:       0.51
# 40. Epoch Avg Loss:       0.51
# 41. Epoch Avg Loss:       0.51
# 42. Epoch Avg Loss:       0.51
# 43. Epoch Avg Loss:       0.51
# 44. Epoch Avg Loss:       0.51
# 45. Epoch Avg Loss:       0.51
# 46. Epoch Avg Loss:       0.51
# 47. Epoch Avg Loss:       0.51
# 48. Epoch Avg Loss:       0.51
# 49. Epoch Avg Loss:       0.51
# 50. Epoch Avg Loss:       0.51
# Train Time:  16.8158
# Total Number of Batches:  8800

# %%
forecast = m.predict_history(forecast_lag=1)
# Out:
# time shape:  (2816, 30)
# lags shape:  (2816, 60)
# Validation MSEs for 1-step ahead:       0.22

# %%
fig = m.plot(forecast)

# %%
fig1 = m.plot_components(forecast)

# %%
fig = m.plot(forecast, max_history=365)

# %%
fig = m.plot(forecast, max_history=90)
